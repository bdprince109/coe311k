# %% [markdown]
# Jacobi Algorithm

# %%
import numpy as np
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

# %% [markdown]
# Gauss-Seidel Algorithm

# %%
import numpy as np
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

# %% [markdown]
# Challenge 6a.

# %%
import time
A=np.array([[10, -1, 2, 0, 0],[-1, 11, -1, 3, 0],[2, -1, 10, -1, 0],[0, 3, -1, 8, -2],[0, 0, 0, -2, 9]])
b=np.array([14, 30, 26, 25, 37])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
t1=time.time()
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
t2=time.time()
print(t2-t1)

#gauss
t3=time.time()
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
t4=time.time()
print(t4-t3)
# Out:
# Solution: [1 2 2 3 4]
# Iterations: 1
# 0.001374959945678711
# Solution: [1 2 2 3 4]
# Iterations: 2
# 0.0015935897827148438

# %% [markdown]
# In this case both the Jacobi and Gauss-Seidel methods converged, however, the Jacobi method converged in one iteration while the Gauss-Seidel method converged in two iterations. The Jacobi method took 0.001374959945678711s, while the Gauss-Seidel method took  0.0015935897827148438s.

# %% [markdown]
# Challenge 6b.

# %%
A=np.array([[1, 2, 3, 0, 0],[2, 1, 2, 3, 0],[3, 2, 1, 2, 3],[0, 3, 2, 1, 2],[0, 0, 3, 2, 1]])
b=np.array([14, 22, 33, 26, 22])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
t1=time.time()
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
t2=time.time()
print(t2-t1)

#gauss
t3=time.time()
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
t4=time.time()
print(t4-t3)
# Out:
# Solution: [-5976176488926883840 -4324294422220818432   125198747742650400
#  -4324294422220818432 -5976176488926883840]
# Iterations: 100
# 0.01271820068359375
# Solution: [-4667072227903264768 -5861557759596381184  5941495520527654912
#     32542205762157592   557173100602271744]
# Iterations: 100
# 0.009589195251464844
# <ipython-input-1-c4ebca5c0dd8>:8: RuntimeWarning: overflow encountered in long_scalars
#   s = sum(A[i][j] * x[j] for j in range(n) if j != i)
# <ipython-input-2-b0b8536a1032>:9: RuntimeWarning: overflow encountered in long_scalars
#   s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
# <ipython-input-2-b0b8536a1032>:10: RuntimeWarning: overflow encountered in long_scalars
#   x_new[i] = (b[i] - s1 - s2) / A[i][i]

# %% [markdown]
# In this case, neither the Jacobi nor the Gauss-Seidel methods converged, with both reaching the max iterations without coming near the actual value. The Jacobi method took .0127s to run through 100 iterations, while the Gauss-Seidel took .0095s to run through 100 iterations
