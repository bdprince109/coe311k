# %% [markdown]
# # In Class Sample Code

# %%
# Importing necessary libraries
import numpy as np
import matplotlib.pyplot as plt
# Step 1: Generate some sample data
# Creating data points that roughly follow a quadratic curve
np.random.seed(0)
x = np.linspace(-5, 5, 50) # 50 points between -5 and 5
y = 2 * x**2 + 3 * x + np.random.randn(50) * 10 # y = 2x^2 + 3x + some noise

# %%
# Step 2: Polynomial fitting using NumPy's polyfit
# Fit a 2nd degree polynomial to the data
degree = 2 # Degree of the polynomial
coefficients = np.polyfit(x, y, degree)
# Print the polynomial coefficients
print("Polynomial Coefficients: ", coefficients)
# Step 3: Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)
# Out:
# Polynomial Coefficients:  [2.09218103 1.58837751 0.60606342]

# %%
# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(x)
# Step 4: Plotting the results
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
# Mean Squared Error (MSE)
mse = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Mean Squared Error: 108.8860
# R-squared: 0.7236

# %% [markdown]
# # Challenge 10a

# %% [markdown]
# ### Least Squares Regression Code

# %%
# Data points
X = np.sort(np.random.uniform(0,10,20))
print(X)
Y = np.random.uniform(0,10,20)
# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")
t=np.linspace(0,10,20)
# Out:
# [0.39187792 0.96098408 0.97101276 1.10375141 1.18727719 1.20196561
#  1.38182951 1.58969584 1.96582362 2.82806963 2.96140198 3.68725171
#  4.68651202 6.0484552  6.56329589 7.39263579 8.2099323  8.37944907
#  9.76459465 9.76761088]
# Slope: -0.07374654583963068, Intercept: 4.393956556631502

# %%
y=m*t+c

# %% [markdown]
# ### Plot Routine

# %%
plt.figure()
plt.title("Least Squares Regression")
plt.plot(X,Y, 'b.')
plt.plot(t,y,'r')
plt.show()

# %% [markdown]
# ### MSE and R^2 Calculations

# %%
mse = np.mean((Y - y)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Mean Squared Error: 7.4726
# R-squared: 0.0023

# %% [markdown]
# ### Degree 3 Polynomial Fit

# %%
degree = 3 # Degree of the polynomial
coefficients = np.polyfit(X, Y, degree)
# Print the polynomial coefficients
print("Polynomial Coefficients: ", coefficients)
# Step 3: Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)
# Out:
# Polynomial Coefficients:  [ 0.04034778 -0.6740136   2.99969856  1.43880664]

# %% [markdown]
# ### Plot Routine

# %%
# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(X)
# Step 4: Plotting the results
plt.scatter(X, Y, color='blue', label='Data points') # Original data points
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# ### Error Calculation

# %%
# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Mean Squared Error: 6.7965
# R-squared: 0.0926

# %% [markdown]
# # Challenge 10B

# %% [markdown]
# ### Loops Through Degrees of Polyfit

# %%
for i in range(1,16):
    degree = i 
    coefficients = np.polyfit(X, Y, degree)
    polynomial = np.poly1d(coefficients)
    y_pred = polynomial(X)
    #Plots curves
    plt.scatter(X, Y, color='blue', label='Data points') # Original data points
    plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
    # Fitted curve
    plt.title('Polynomial Fit')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.show()
    #Calculates Error
    mse = np.mean((Y - y_pred)**2)
    print(f'Mean Squared Error: {mse:.4f}')
    ss_total = np.sum((Y - np.mean(Y))**2)
    ss_res = np.sum((Y - y_pred)**2)
    r_squared = 1 - (ss_res / ss_total)
    print(f'R-squared: {r_squared:.4f}')
    print(i)
# Out:
# Mean Squared Error: 7.4355
# R-squared: 0.0073
# 1
# Mean Squared Error: 7.3156
# R-squared: 0.0233
# 2
# Mean Squared Error: 6.7965
# R-squared: 0.0926
# 3
# Mean Squared Error: 6.7883
# R-squared: 0.0937
# 4
# Mean Squared Error: 6.7882
# R-squared: 0.0937
# 5
# Mean Squared Error: 6.6218
# R-squared: 0.1159
# 6
# Mean Squared Error: 6.6102
# R-squared: 0.1175
# 7
# Mean Squared Error: 6.3353
# R-squared: 0.1542
# 8
# Mean Squared Error: 6.1969
# R-squared: 0.1727
# 9
# Mean Squared Error: 5.5430
# R-squared: 0.2600
# 10
# Mean Squared Error: 5.2784
# R-squared: 0.2953
# 11
# Mean Squared Error: 4.1751
# R-squared: 0.4426
# 12
# Mean Squared Error: 2.1543
# R-squared: 0.7124
# 13
# Mean Squared Error: 1.7276
# R-squared: 0.7694
# 14
# Mean Squared Error: 1.0712
# R-squared: 0.8570
# 15

# %% [markdown]
# # C

# %% [markdown]
# ### N Degree Vander Matrix
# Solved for polynomial fit

# %%
degree=9
V = np.vander(Y, N=degree+1, increasing=True)
# V.T * V
VT_V = np.dot(V.T, V)
# V.T * y
VT_y = np.dot(V.T, y)
# Solve for a (coefficients)
coefficients = np.linalg.solve(VT_V, VT_y)
polynomial = np.poly1d(coefficients)

# %% [markdown]
# ### Plot Routine

# %%
# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(X)
# Step 4: Plotting the results
plt.scatter(X, Y, color='blue', label='Data points') # Original data points
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# ### Loops Through i-1 Degrees

# %%
for i in range(1,16):
    degree = i 
    V = np.vander(Y, N=degree+1, increasing=True)
    VT_V = np.dot(V.T, V)
    VT_y = np.dot(V.T, y)
    coefficients = np.linalg.solve(VT_V, VT_y)
    polynomial = np.poly1d(coefficients)
    y_pred = polynomial(X)
    plt.scatter(X, Y, color='blue', label='Data points') # Original data points
    plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
    # Fitted curve
    plt.title('Polynomial Fit')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.show()
    mse = np.mean((Y - y_pred)**2)
    print(f'Mean Squared Error: {mse:.4f}')
    ss_total = np.sum((Y - np.mean(Y))**2)
    ss_res = np.sum((Y - y_pred)**2)
    r_squared = 1 - (ss_res / ss_total)
    print(f'R-squared: {r_squared:.4f}')
    print(i)
# Out:
# Mean Squared Error: 322.0492
# R-squared: -41.9961
# 1
# Mean Squared Error: 25286.0188
# R-squared: -3374.8810
# 2
# Mean Squared Error: 1945335.4190
# R-squared: -259716.4716
# 3
# Mean Squared Error: 165531718.5122
# R-squared: -22099776.2336
# 4
# Mean Squared Error: 13946194076.7661
# R-squared: -1861925828.8208
# 5
# Mean Squared Error: 1233262312746.0088
# R-squared: -164650150599.7165
# 6
# Mean Squared Error: 110075924143654.5000
# R-squared: -14695995572433.5645
# 7
# Mean Squared Error: 10173555290798788.0000
# R-squared: -1358249087369718.7500
# 8
# Mean Squared Error: 947189171098535936.0000
# R-squared: -126457151943197968.0000
# 9
# Mean Squared Error: 88675088795528167424.0000
# R-squared: -11838816911712905216.0000
# 10
# Mean Squared Error: 7893545729077147598848.0000
# R-squared: -1053850003874936782848.0000
# 11
# Mean Squared Error: 773561778689490854871040.0000
# R-squared: -103276539016735623217152.0000
# 12
# Mean Squared Error: 73694947522732203299569664.0000
# R-squared: -9838851056035423185797120.0000
# 13
# Mean Squared Error: 6988175637148445264595386368.0000
# R-squared: -932976025610309173761802240.0000
# 14
# Mean Squared Error: 666361157696045347895842439168.0000
# R-squared: -88964418871135831372807012352.0000
# 15
