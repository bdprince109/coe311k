# %% [markdown]
# # In Class Sample Code

# %%
# Importing necessary libraries
import numpy as np
import matplotlib.pyplot as plt
# Step 1: Generate some sample data
# Creating data points that roughly follow a quadratic curve
np.random.seed(0)
x = np.linspace(-5, 5, 50) # 50 points between -5 and 5
y = 2 * x**2 + 3 * x + np.random.randn(50) * 10 # y = 2x^2 + 3x + some noise

# %%
# Step 2: Polynomial fitting using NumPy's polyfit
# Fit a 2nd degree polynomial to the data
degree = 2 # Degree of the polynomial
coefficients = np.polyfit(x, y, degree)
# Print the polynomial coefficients
print("Polynomial Coefficients: ", coefficients)
# Step 3: Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)
# Out:
# Polynomial Coefficients:  [2.09218103 1.58837751 0.60606342]

# %%
# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(x)
# Step 4: Plotting the results
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# # Challenge 10a

# %%
# Mean Squared Error (MSE)
mse = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Mean Squared Error: 108.8860
# R-squared: 0.7236

# %%
# Data points
X = np.sort(np.random.uniform(0,10,20))
print(X)
Y = np.random.uniform(0,10,20)
# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")
t=np.linspace(0,10,20)
# Out:
# [0.39187792 0.96098408 0.97101276 1.10375141 1.18727719 1.20196561
#  1.38182951 1.58969584 1.96582362 2.82806963 2.96140198 3.68725171
#  4.68651202 6.0484552  6.56329589 7.39263579 8.2099323  8.37944907
#  9.76459465 9.76761088]
# Slope: -0.07374654583963068, Intercept: 4.393956556631502

# %%
y=-0.1470241924788173*t+ 5.085320885624438

# %%
plt.figure()
plt.title("Least Squares Regression")
plt.plot(X,Y, 'b.')
plt.plot(t,y,'r')
plt.show()

# %%
# Mean Squared Error (MSE)
mse = np.mean((Y - y)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Mean Squared Error: 7.6097
# R-squared: -0.0160

# %%
degree = 3 # Degree of the polynomial
coefficients = np.polyfit(X, Y, degree)
# Print the polynomial coefficients
print("Polynomial Coefficients: ", coefficients)
# Step 3: Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)
# Out:
# Polynomial Coefficients:  [ 0.04034778 -0.6740136   2.99969856  1.43880664]

# %%
# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(X)
# Step 4: Plotting the results
plt.scatter(X, Y, color='blue', label='Data points') # Original data points
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Mean Squared Error: 6.7965
# R-squared: 0.0926

# %% [markdown]
# # Challenge 10B

# %%
for i in range(1,16):
    degree = i 
    coefficients = np.polyfit(X, Y, degree)
    polynomial = np.poly1d(coefficients)
    y_pred = polynomial(X)
    plt.scatter(X, Y, color='blue', label='Data points') # Original data points
    plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
    # Fitted curve
    plt.title('Polynomial Fit')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.show()
    mse = np.mean((Y - y_pred)**2)
    print(f'Mean Squared Error: {mse:.4f}')
    ss_total = np.sum((Y - np.mean(Y))**2)
    ss_res = np.sum((Y - y_pred)**2)
    r_squared = 1 - (ss_res / ss_total)
    print(f'R-squared: {r_squared:.4f}')
    print(i)
# Out:
# Mean Squared Error: 7.4355
# R-squared: 0.0073
# 1
# Mean Squared Error: 7.3156
# R-squared: 0.0233
# 2
# Mean Squared Error: 6.7965
# R-squared: 0.0926
# 3
# Mean Squared Error: 6.7883
# R-squared: 0.0937
# 4
# Mean Squared Error: 6.7882
# R-squared: 0.0937
# 5
# Mean Squared Error: 6.6218
# R-squared: 0.1159
# 6
# Mean Squared Error: 6.6102
# R-squared: 0.1175
# 7
# Mean Squared Error: 6.3353
# R-squared: 0.1542
# 8
# Mean Squared Error: 6.1969
# R-squared: 0.1727
# 9
# Mean Squared Error: 5.5430
# R-squared: 0.2600
# 10
# Mean Squared Error: 5.2784
# R-squared: 0.2953
# 11
# Mean Squared Error: 4.1751
# R-squared: 0.4426
# 12
# Mean Squared Error: 2.1543
# R-squared: 0.7124
# 13
# Mean Squared Error: 1.7276
# R-squared: 0.7694
# 14
# Mean Squared Error: 1.0712
# R-squared: 0.8570
# 15

# %% [markdown]
# # C

# %%
degree=9
V = np.vander(Y, N=degree+1, increasing=True)
# V.T * V
VT_V = np.dot(V.T, V)
# V.T * y
VT_y = np.dot(V.T, y)
# Solve for a (coefficients)
coefficients = np.linalg.solve(VT_V, VT_y)
polynomial = np.poly1d(coefficients)

# %%
# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(X)
# Step 4: Plotting the results
plt.scatter(X, Y, color='blue', label='Data points') # Original data points
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
for i in range(1,16):
    degree = i 
    V = np.vander(Y, N=degree+1, increasing=True)
    VT_V = np.dot(V.T, V)
    VT_y = np.dot(V.T, y)
    coefficients = np.linalg.solve(VT_V, VT_y)
    polynomial = np.poly1d(coefficients)
    y_pred = polynomial(X)
    plt.scatter(X, Y, color='blue', label='Data points') # Original data points
    plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
    # Fitted curve
    plt.title('Polynomial Fit')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.show()
    mse = np.mean((Y - y_pred)**2)
    print(f'Mean Squared Error: {mse:.4f}')
    ss_total = np.sum((Y - np.mean(Y))**2)
    ss_res = np.sum((Y - y_pred)**2)
    r_squared = 1 - (ss_res / ss_total)
    print(f'R-squared: {r_squared:.4f}')
    print(i)
# Out:
# Mean Squared Error: 379.7098
# R-squared: -49.6942
# 1
# Mean Squared Error: 27648.5914
# R-squared: -3690.3029
# 2
# Mean Squared Error: 2056329.5323
# R-squared: -274535.0526
# 3
# Mean Squared Error: 177689305.3170
# R-squared: -23722909.0234
# 4
# Mean Squared Error: 14504316122.9084
# R-squared: -1936439480.9459
# 5
# Mean Squared Error: 1266890916250.2935
# R-squared: -169139831808.8532
# 6
# Mean Squared Error: 110640446664424.5938
# R-squared: -14771363737909.5137
# 7
# Mean Squared Error: 10221847161189008.0000
# R-squared: -1364696429229080.0000
# 8
# Mean Squared Error: 949747731150648576.0000
# R-squared: -126798739692655184.0000
# 9
# Mean Squared Error: 88662435484622536704.0000
# R-squared: -11837127595883923456.0000
# 10
# Mean Squared Error: 7439490855339764482048.0000
# R-squared: -993230132036490100736.0000
# 11
# Mean Squared Error: 756112184111427777200128.0000
# R-squared: -100946881858233566232576.0000
# 12
# Mean Squared Error: 72373179686604738945613824.0000
# R-squared: -9662384726830087327973376.0000
# 13
# Mean Squared Error: 6851604420076935081229287424.0000
# R-squared: -914742701502254311190560768.0000
# 14
# Mean Squared Error: 655184358080578992399519318016.0000
# R-squared: -87472228831027496336268197888.0000
# 15
