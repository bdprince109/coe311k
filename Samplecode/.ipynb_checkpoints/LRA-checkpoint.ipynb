# %%
import numpy as np
import matplotlib.pyplot as plt
"""
Pc=450*6894.76#chamber pressure
At=(1.540*.0254)**2/4*np.pi#throat diameter
C=1.26 #heat capacity ratio
Rm=8.31446/.02457 #Gas Constant/molar mass
T=3287 #temperature
#mDotO = 1/(1.2)*Pc*At*(2/(C+1))**((C+1)/(2*(C-1)))*np.sqrt(C/(Rm*T)) #[kg/s]mass flow of injector
"""
mDotO= 1.35 # kg/s
print(mDotO)
Cd = .5; # Discharge Coefficient
p = 1000
dP_pa = 689476 
Ao = (mDotO) / (Cd * np.sqrt(2 * p * dP_pa)) ;
print(Ao)
Dio = .00238 ; # m, 3/32 in
Aio = np.pi * (Dio**2) / 4 ;
print(Aio)
N = Ao / Aio ;
print(N)
# Out:
# 1.35
# 7.270917043108214e-05
# 4.448809356748507e-06
# 16.343512297461753

# %% [markdown]
# Injector OD 4 in
