# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print(5+10)
# Out:
# 15

# %%
print(True)
# Out:
# True

# %%
numIn=5
myfile= open("test.dat",'w')
myfile.write("numIn")
myfile.write("\n")
myfile.write("HelloWorld")
myfile.close()

# %%
myfile2= open("test.dat", 'r')
content=myfile2.read()
myfile2.close()
print(content) #must loop
# Out:
# numIn
# HelloWorld

# %%
a=2
b=3 
print(b>a)
# Out:
# True

# %%
for i in range(0,3):
    print(i, i**2)
# Out:
# 0 0
# 1 1
# 2 4

# %%
myList=["Ben",10,"Orange",42,"Alex",9]
for i in myList:
    print(i,type(i))
# Out:
# Ben <class 'str'>
# 10 <class 'int'>
# Orange <class 'str'>
# 42 <class 'int'>
# Alex <class 'str'>
# 9 <class 'int'>

# %%
print(myList[2:])
# Out:
# ['Orange', 42, 'Alex', 9]

# %%
print("Ben" in myList)
print(2 in myList)
# Out:
# True
# False

# %%
import math
def calcH(a,b):
    h=math.sqrt(a*a + b*b)
    return h

# %%
H=calcH(3,4)
print(H)
# Out:
# 5.0
